# %% [markdown]
# # Kolerasyon Grafikleri

# %% [markdown]
# Scater plot

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df, x = "total_bill", y="tip");

# %% [markdown]
# Çaprazlamalar

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", hue = "sex");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", hue = "time");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", hue = "time", style="time");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", hue = "day", style="time");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", hue = "size");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", size = "size");

# %%
sns.scatterplot(data=df, x="total_bill", y = "tip", size = "size", hue="size");

# %%
sns.scatterplot(data=df, x="total_bill", y = "size", size = "tip", hue="tip");

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
